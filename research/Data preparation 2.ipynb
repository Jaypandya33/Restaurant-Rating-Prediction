# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("cleaned_zomato.csv")
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# ...

# %%
df.isnull().sum()
# Out:
# name                              0
# online_order                      0
# book_table                        0
# rate                           7775
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     346
# listed_in(type)                   0
# dtype: int64

# %%
df['rate'] = df['rate'].str.replace('/5', '', regex=False)
df.head()
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type)
# 0                         800          Buffet
# 1                         800          Buffet
# ...

# %%
df['rate'] = pd.to_numeric(df['rate'], errors='coerce')

# %%
mean_rate = df['rate'].mean()

mean_rate
# Out:
# 3.700448817952718

# %%
df['rate'] = df['rate'].fillna(mean_rate)
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#   approx_cost(for two people) listed_in(type)
# 0                         800          Buffet
# 1                         800          Buffet
# ...

# %%
df.sample()
# Out:
#              name online_order book_table      rate  votes      location  \
# 39055  Safa Hotel           No         No  3.700449      0  Shivajinagar
#
#          rest_type               cuisines approx_cost(for two people)  \
# 39055  Quick Bites  North Indian, Biryani                         200
#
#       listed_in(type)
# 39055        Dine-out

# %%
df['approx_cost(for two people)'] = pd.to_numeric(df['approx_cost(for two people)'], errors='coerce')

# %%
mean_rate = df['approx_cost(for two people)'].mean()

mean_rate
# Out:
# 416.63011202591446

# %%
df['approx_cost(for two people)'] = df['approx_cost(for two people)'].fillna(mean_rate)
df.head()
# Out:
#                     name online_order book_table  rate  votes      location  \
# 0                  Jalsa          Yes        Yes   4.1    775  Banashankari
# 1         Spice Elephant          Yes         No   4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No   3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No   3.7     88  Banashankari
# 4          Grand Village           No         No   3.8    166  Basavanagudi
#
#              rest_type                        cuisines  \
# 0        Casual Dining  North Indian, Mughlai, Chinese
# 1        Casual Dining     Chinese, North Indian, Thai
# 2  Cafe, Casual Dining          Cafe, Mexican, Italian
# 3          Quick Bites      South Indian, North Indian
# 4        Casual Dining        North Indian, Rajasthani
#
#    approx_cost(for two people) listed_in(type)
# 0                        800.0          Buffet
# 1                        800.0          Buffet
# ...

# %%
df['rest_type'] = df['rest_type'].fillna('Others')

# %%
df[df['rest_type'] == 'Others'].head()
# Out:
#                       name online_order book_table      rate  votes  \
# 999        Mughlai Kitchen          Yes         No  3.500000    269
# 1300  Eat & Joy Restaurant          Yes         No  3.000000      7
# 1376   Kababish Restaurant          Yes         No  3.600000     15
# 1565    Goli Vada Pav No 1           No         No  3.700449      0
# 1637        Ammi's Biryani           No         No  2.400000    392
#
#                location rest_type                               cuisines  \
# 999                 BTM    Others  Mughlai, North Indian, Chinese, Momos
# 1300           JP Nagar    Others                 Fast Food, Finger Food
# 1376                BTM    Others         North Indian, Chinese, Arabian
# 1565  Bannerghatta Road    Others                    Street Food, Burger
# 1637  Bannerghatta Road    Others                  Biryani, North Indian
#
#       approx_cost(for two people) listed_in(type)
# 999                         600.0        Delivery
# ...

# %%
df['cuisines'] = df['cuisines'].fillna('Others')

# %%
df[df['cuisines'] == 'Others'].head()
# Out:
#                       name online_order book_table      rate  votes  \
# 438   The House Of Vadapav          Yes         No  3.700449      0
# 440             Lassi Spot          Yes         No  3.300000      4
# 759   The House Of Vadapav          Yes         No  3.700449      0
# 1662       Papa Khan Rasoi           No         No  3.700449      0
# 4037            Chai Point          Yes         No  3.700449      0
#
#                 location                   rest_type cuisines  \
# 438         Banashankari                 Quick Bites   Others
# 440   Kumaraswamy Layout               Beverage Shop   Others
# 759         Banashankari                 Quick Bites   Others
# 1662                 NaN                      Others   Others
# 4037        Marathahalli  Beverage Shop, Quick Bites   Others
#
#       approx_cost(for two people) listed_in(type)
# 438                    150.000000        Delivery
# 440                    100.000000        Delivery
# ...

# %%
df['location'] = df['location'].fillna('Others')

# %%
df[df['location'] == 'Others'].head()
# Out:
#                            name online_order book_table      rate  votes  \
# 1662            Papa Khan Rasoi           No         No  3.700449      0
# 9874            Papa Khan Rasoi           No         No  3.700449      0
# 13693  Mohabbat Desi Restaurant           No         No  3.700449      0
# 16351             Desi Chatkara           No         No  3.700449      0
# 26432    New Taj Biryani Centre           No         No  3.700449      0
#
#       location rest_type cuisines  approx_cost(for two people) listed_in(type)
# 1662    Others    Others   Others                   416.630112        Delivery
# 9874    Others    Others   Others                   416.630112        Delivery
# 13693   Others    Others   Others                   416.630112        Delivery
# 16351   Others    Others   Others                   416.630112        Delivery
# 26432   Others    Others   Others                   416.630112        Dine-out

# %%
print(df)
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table      rate  votes                    location  \
# 0            Yes  4.100000    775                Banashankari
# ...

# %%
df.to_csv('cleaned_zomato1.csv', index=False)
